# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
qbits = [128, 512, 1152, 2048, 5640]#
year = [2011, 2013, 2015, 2017, 2020]

# %%
plt.plot(year, qbits)
plt.xlabel('year')
plt.ylabel('qubits')
plt.savefig('../../80_figures/02_Background/dwave_qbits_history.png')
